# %% [raw]
# We have to regularly retrain the model on new data
# - Expanding windows
# - Sliding windows
#
# Sliding windows will only have higher testing set accuracy if there has been data shift

# %%
import pandas as pd
import numpy as np

# %%
data_a = pd.read_csv('arrh.csv')
data_a.head()
# Out:
#    age  sex  height  weight  QRSduration  PRinterval  Q-Tinterval  Tinterval  \
# 0   75    0     190      80           91         193          371        174
# 1   56    1     165      64           81         174          401        149
# 2   54    0     172      95          138         163          386        185
# 3   55    0     175      94          100         202          380        179
# 4   75    0     190      80           88         181          360        177
#
#    Pinterval  QRS  ...  chV6_QwaveAmp  chV6_RwaveAmp  chV6_SwaveAmp  \
# 0        121  -16  ...            0.0            9.0           -0.9
# 1         39   25  ...            0.0            8.5            0.0
# 2        102   96  ...            0.0            9.5           -2.4
# 3        143   28  ...            0.0           12.2           -2.2
# 4        103  -16  ...            0.0           13.1           -3.6
#
#    chV6_RPwaveAmp  chV6_SPwaveAmp  chV6_PwaveAmp  chV6_TwaveAmp  chV6_QRSA  \
# 0             0.0             0.0            0.9            2.9       23.3
# 1             0.0             0.0            0.2            2.1       20.4
# 2             0.0             0.0            0.3            3.4       12.3
# 3             0.0             0.0            0.4            2.6       34.6
# 4             0.0             0.0           -0.1            3.9       25.4
#
#    chV6_QRSTA  class
# 0        49.4      0
# 1        38.8      0
# 2        49.0      0
# 3        61.6      1
# 4        62.8      0
#
# [5 rows x 280 columns]

# %%
data_a.shape
# Out:
# (452, 280)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, roc_auc_score

# %% [raw]
# Trying window sizes from 10-100 starting at t=400
#
# The new data is from t=400 to t=452

# %%
t_now = 400

# %%
data_past = data_a.iloc[:t_now,]
data_new = data_a.iloc[t_now:]
print(data_past.shape)
print(data_new.shape)

x_test, y_test = data_new.drop('class', 1), data_new['class']
# Out:
# (400, 280)
# (52, 280)
# C:\Users\Jerrold's work\AppData\Local\Temp\ipykernel_13832\3377173372.py:6: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x_test, y_test = data_new.drop('class', 1), data_new['class']

# %%
x_train, y_train = data_past.iloc[:,:-1], data_past.iloc[:,-1]

preds = GaussianNB().fit(x_train, y_train).predict(x_test)
f1_score(y_test, preds)
# Out:
# 0.8378378378378378

# %%
x_train
# Out:
#      age  sex  height  weight  QRSduration  PRinterval  Q-Tinterval  \
# 0     75    0     190      80           91         193          371
# 1     56    1     165      64           81         174          401
# 2     54    0     172      95          138         163          386
# 3     55    0     175      94          100         202          380
# 4     75    0     190      80           88         181          360
# ..   ...  ...     ...     ...          ...         ...          ...
# 395   61    1     156      77          147         147          509
# 396   45    1     158      65           82         122          336
# 397   30    1     160      52          110         154          426
# 398   47    0     175      94          108         173          341
# 399   71    1     165      82           82         182          369
#
#      Tinterval  Pinterval  QRS  ...  chV6_JJwaveAmp  chV6_QwaveAmp  \
# 0          174        121  -16  ...            -0.3            0.0
# 1          149         39   25  ...            -0.5            0.0
# 2          185        102   96  ...             0.9            0.0
# 3          179        143   28  ...             0.1            0.0
# 4          177        103  -16  ...            -0.4            0.0
# ..         ...        ...  ...  ...             ...            ...
# 395        327         68   31  ...            -1.2            0.0
# 396        174         63   38  ...             0.2           -0.5
# 397        154         94  102  ...             0.5            0.0
# 398        168         99  -49  ...            -0.1            0.0
# 399        152        107   33  ...             0.0            0.0
#
#      chV6_RwaveAmp  chV6_SwaveAmp  chV6_RPwaveAmp  chV6_SPwaveAmp  \
# 0              9.0           -0.9             0.0             0.0
# 1              8.5            0.0             0.0             0.0
# 2              9.5           -2.4             0.0             0.0
# 3             12.2           -2.2             0.0             0.0
# 4             13.1           -3.6             0.0             0.0
# ..             ...            ...             ...             ...
# 395            5.1            0.0             0.0             0.0
# 396            7.8           -0.7             0.0             0.0
# 397            6.5           -2.4             0.0             0.0
# 398            7.7           -4.0             0.0             0.0
# 399            6.2           -3.5             0.0             0.0
#
#      chV6_PwaveAmp  chV6_TwaveAmp  chV6_QRSA  chV6_QRSTA
# 0              0.9            2.9       23.3        49.4
# 1              0.2            2.1       20.4        38.8
# 2              0.3            3.4       12.3        49.0
# 3              0.4            2.6       34.6        61.6
# 4             -0.1            3.9       25.4        62.8
# ..             ...            ...        ...         ...
# 395            0.6           -1.9       30.6        -2.4
# 396           -0.1            2.5       17.6        40.6
# 397            0.5            2.8       15.2        40.9
# 398            0.9            1.5        2.5        20.2
# 399            0.6            1.3        2.6        11.4
#
# [400 rows x 279 columns]

# %%
accuracies = []
aucs = []

wrange = range(100,410,10)

# Loop over window sizes
for w_size in wrange:
    # Define sliding window
    t_start = t_now - w_size
    sliding = data_past.loc[t_start:t_now]
    
    # Extract X and y from the sliding window
    x, y = sliding.iloc[:,:-1], sliding.iloc[:,-1]
    
    # Fit the classifier and store the F1 score
    preds = GaussianNB().fit(x, y).predict(x_test)
    accuracies.append(f1_score(y_test, preds))
    aucs.append(roc_auc_score(y_test, preds))

# Estimate the best performing window size
optimal_window_1 = wrange[np.argmax(accuracies)]
optimal_window_2 = wrange[np.argmax(aucs)]

print(optimal_window_1, optimal_window_2)
# Out:
# 120 190

# %%
accuracies
# Out:
# [0.8333333333333333,
#  0.8333333333333333,
#  0.8493150684931509,
#  0.8493150684931509,
#  0.8493150684931509,
#  0.8493150684931509,
#  0.8493150684931509,
#  0.8493150684931509,
#  0.8493150684931509,
#  0.8450704225352113,
#  0.8450704225352113,
#  0.8450704225352113,
#  0.8450704225352113,
#  0.8333333333333333,
#  0.8333333333333333,
#  0.821917808219178,
#  0.821917808219178,
#  0.821917808219178,
#  0.821917808219178,
#  0.8333333333333333,
#  0.821917808219178,
#  0.8333333333333333,
#  0.821917808219178,
#  0.821917808219178,
#  0.821917808219178,
#  0.821917808219178,
#  0.8378378378378378,
#  0.8378378378378378,
#  0.8266666666666667,
#  0.8378378378378378,
#  0.8378378378378378]

# %%
aucs
# Out:
# [0.7177033492822967,
#  0.7177033492822967,
#  0.7328548644338119,
#  0.7328548644338119,
#  0.7328548644338119,
#  0.7328548644338119,
#  0.7328548644338119,
#  0.7328548644338119,
#  0.7328548644338119,
#  0.7440191387559809,
#  0.7440191387559809,
#  0.7440191387559809,
#  0.7440191387559809,
#  0.7177033492822967,
#  0.7177033492822967,
#  0.6913875598086124,
#  0.6913875598086124,
#  0.6913875598086124,
#  0.6913875598086124,
#  0.7177033492822967,
#  0.6913875598086124,
#  0.7177033492822967,
#  0.6913875598086124,
#  0.6913875598086124,
#  0.6913875598086124,
#  0.6913875598086124,
#  0.7065390749601277,
#  0.7065390749601277,
#  0.6802232854864434,
#  0.7065390749601277,
#  0.7065390749601277]

# %% [markdown]
# ## Conclusion:
# ### It seems a window size of 120-200 is the optimal training data size
